# %%
'Etapa bronze ok'

# %%
# %sh
cd /Workspace/Users/hugomeloqueiroz17@gmail.com/projeto-udemy
git status

# %%
# %sh
cd /Workspace/Users/hugomeloqueiroz17@gmail.com/projeto-udemy
git pull origin main

# %%
# %sh
cd /Workspace/Users/hugomeloqueiroz17@gmail.com/projeto-udemy
git add 01.bronze/
git add dados/
